# %% [markdown]
# Question 1
#
# Create a function that takes a number as an argument and returns True or False depending on whether the number is symmetrical or not. A number is symmetrical when it is the same as its reverse.

# %%
def symmetrical_num(nums):
    return str(nums) == str(nums)[::-1]

# %%
symmetrical_num(1212)
# Out:
# False

# %% [markdown]
# Question 2
#
# Given a string of numbers separated by a comma and space, return the product of the numbers.

# %%
a,b= map(int,input('enter a value \n').split(', '))
multiple_num= a*b
print(multiple_num)
# Out:
# enter a value
# 5, 6
# 30

# %% [markdown]
# Question 3
#
# Create a function that squares every digit of a number.

# %%
import math
def squaring(nums):
    s =' '
    for i in str(nums):
        s =s + str(int(i)**2)
    return int(s)

# %%
squaring(2356)
# Out:
# 492536

# %% [markdown]
# Question 4
#
# Create a function that sorts a list and removes all duplicate items from it.

# %%
def sorted_list(*args):
    x = set(args)
    return list(sorted(x))

# %%
sorted_list(100,100,5,8,3)
# Out:
# [3, 5, 8, 100]

# %% [markdown]
# Question 5
#
# Create a function that returns the mean of all digits.

# %%
import statistics
#val must in list format
def mean(val):
    x =statistics.mean(val)
    return round(x)

# %%
mean([10,10])
# Out:
# 10
