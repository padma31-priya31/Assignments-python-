# %% [markdown]
# ## Assignment -1

# %% [raw]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
#
# * -      -(Expression)
# 'hello'  -(Values)
# -87.8    -(Values)
# -        -(Expression)
# /        -(Expression)
# +	     -(Expression)
# 6        - (Values)

# %% [raw]
# 2. What is the difference between string and variable?
#                  Variable is a kind of  string we used that to store our data , like variable helps to access the data which we stored in that  ,we can access that data anywhere while we calling that variable name. In python variable name must be unique and it cannot be a inbuilt function of python, spaces and some special characters won’t be accept as a variable name.
#                   String is group of characters and in python it must be write in single quotes or in double quotes otherwise we will get an error. String means inside that quotes we can use any special characters and numbers as well all we need is that quotations to show that it is a string in python.

# %% [raw]
# 3. Describe three different data types.
#                   Integer(int) – it is a numerical data type eg : 0,1,2,100 ….etc considered as a int in python.
#                   Boolean(bool) – True or False
#                   String(str) – ‘hjhdu59 ‘ ,  ” wwh@“ anything inside these quoatations
#                   Float – decimal points eg:12.6677 ,67.4
#                   Complex -   75+8i

# %% [raw]
# 4. What is an expression made up of? What do all expressions do?
#                Expression is performing some mathematical operations with the help of arithmetic operators, logical operations, relational operator, membership operator, assignment operator etc….It evaluate the combination of values and variables. And give some result about that.

# %% [raw]
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#        Statements – Statement means we can use any operators but it won’t give us a result in output it can’t evaluate it gives only a instruction.
#       Expression – Expression means it can be evaluate and it will gives us a result or output based on our statement.

# %% [raw]
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1

# %%
#solution for 6th qs

bacon =22
bacon + 1
# Out:
# 23

# %% [raw]
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3

# %%
#solution for 7th qs
print('spam' + 'spamspam')
print('spam' * 3)
# Out:
# spamspamspam
# spamspamspam

# %% [raw]
# 8. Why is eggs a valid variable name while 100 is invalid?
#           Based on the python axioms we can use numbers as a variable name we cannot use that numbers in starting variable name. Because  in python variables must be start with string so that only eggs is a valid variable and 100 is invalid one.

# %% [raw]
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
# 1.	int() for integer
# 2.	flaot() for floating-point
# 3.	str() for string

# %%
#solution for 9th qs
int(),float(),str()
# Out:
# (0, 0.0, '')

# %% [raw]
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'
# ANS:
#
# Because of string + string can only be concatenated in python .string + integer cannot be concatenate so that only error occur .

# %%
#solution for 10th qs
'I have eaten ' + str(99) + ' burritos.'
# Out:
# 'I have eaten 99 burritos.'
