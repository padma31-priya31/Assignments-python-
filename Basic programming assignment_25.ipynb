# %% [markdown]
# ### Question1:
# Create a function that takes three integer arguments (a, b, c) and returns the amount of integers which are of equal value.

# %%
def fun(a,b,c):
    if a==b==c:
        return 3
    elif a==b or b==c or c==a:
        return 2
    else:
        return 0

# %%
fun(3,9,7)
# Out:
# 0

# %% [markdown]
# ### Question2:
#
# Write a function that converts a dictionary into a list of keys-values tuples.

# %%
def fun(**kwargs):
    a = kwargs.items()
    b =list(a)
    b.sort()
    return b

# %%
fun(name="ria",age =20,born_in ="india")
# Out:
# [('age', 20), ('born_in', 'india'), ('name', 'ria')]

# %% [markdown]
# ### Question3:
#
# Write a function that creates a dictionary with each (key, value) pair being the (lower case, upper case) versions of a letter, respectively.

# %%
def fun1(*args):
    result =map(lambda x:x+x.upper(),args)
    a =dict(result)
    return a

# %%
fun1('a','b','c','d','e')
# Out:
# {'a': 'A', 'b': 'B', 'c': 'C', 'd': 'D', 'e': 'E'}

# %% [markdown]
# ### Question4:
#
# Write a function, that replaces all vowels in a string with a specified vowel.

# %%
def fun3(some_tx,k):
    vowels ="AaEeIiOoUu"
    for tx in vowels:
        some_tx=some_tx.replace(tx,k)
    return some_tx

# %%
fun3('padma priya','k')
# Out:
# 'pkdmk prkyk'

# %% [markdown]
# ### Question5:
#
# Create a function that takes a string as input and capitalizes a letter if its ASCII code is even and returns its lower case version if its ASCII code is odd.

# %%
def fun4(some_str):
    l=[]
    for i in range(len(some_str)):
        if ord(some_str[i])%2==0:
            l.append(some_str[i].capitalize())
        else:
            l.append(some_str[i].lower())
    return ''.join(l)

# %%
fun4('i love this journey')
# Out:
# 'i LoVe THis JouRNey'
