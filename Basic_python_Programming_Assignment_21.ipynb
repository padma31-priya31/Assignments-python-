# %% [markdown]
# Question1
#
# Write a function that takes a list and a number as arguments. Add the number to the end of the list, then remove the first element of the list. The function should then return the updated list.

# %%
def fun(lst):
    x = lst.insert((int(input())),int(input()))
    z = lst.remove(int(input()))
    return lst

# %%
fun([3,4,5,6])
# Out:
# 5
# 100
# 3
# [4, 5, 6, 100]

# %% [markdown]
# Question2
#
# Create the function that takes a list of dictionaries and returns the sum of people's budgets.

# %%
list_dic = [{'Name':'Priya','Budget':500},
            {'Name':'Kirthi','Budget':1000}]

key = 'Budget'
val_of_key = [i[key] for i in list_dic]
print(sum(val_of_key))
# Out:
# 1500

# %% [markdown]
# Question3
#
# Create a function that takes a string and returns a string with its letters in alphabetical order.

# %%
def sorted_string(str):
    return ' '.join(sorted(str))

# %%
sorted_string('HAR HAR MAHADEV')
# Out:
# '    A A A A D E H H H M R R V'

# %% [markdown]
# Question4
#
# Suppose that you invest $10,000 for 10 years at an interest rate of 6% compounded monthly. What will be the value of your investment at the end of the 10 year period?
# Create a function that accepts the principal p, the term in years t, the interest rate r, and the number of compounding periods per year n. The function returns the value at the end of term rounded to the nearest cent.

# %%
def compound_interest(principle, rate, time):
 
    # Calculates compound interest
    Amount = principle * (pow((1 + rate / 100), time))
    CI = Amount - principle
    print("Compound interest is", CI)

# %%
compound_interest(10000,0.06, 10)
# Out:
# Compound interest is 60.162259472348524

# %% [markdown]
# Question5
#
# Write a function that takes a list of elements and returns only the integers.

# %%
def list_of_elements(*args):
    l=[]
    for i in args:
        for j in i:
            if type(j)==int:
                l.append(j)
    return l

# %%
list_of_elements(['Padhu',27,"Riya",2010])
# Out:
# [27, 2010]
